# %% [markdown]
# ## Learning figures
#
# In this notebook, we focus on the generating "learning figures" in Python. The goal is to show to plot 1) how input profile learns from episode to episode, 2) showing the state evolution for each episode.

# %% [markdown]
# ## 1. Generation
#
# We first simulate dfn_gym with the saved Actor-Critic parameters. The output of this block is to save all the information during learning process. Strictly, it's

# %%
import gym
import torch

from ddpg_agent import Agent
import ipdb

import logz
import scipy.signal
import gym

# import gym_dfn
from gym_dfn.envs.dfn_env import *

from gym_dfn.envs.ParamFile_LGC import p

import statistics
import pickle
import os
from settings_file import*

#------------ For PCA 
from numpy import linalg as LA
import scipy.io as sio
data = sio.loadmat('PCA_DFN_info.mat')
data_mu = data['time_states_mu']
data_std = data['time_states_std']
data_PCA = data['PCA_trans']
# Out:
# cpu

# %%
def normalize_states(state):

    csn_max = 3.0542e+04
    csp_max = 4.9521e+04
    ce0 = 1.0e3
    T_amb = 298.15

    # ipdb.set_trace()

    N_cavgn = p['Nxn']-1
    N_cavgp = p['Nxp']-1
    N_cex = p['Nxn']-1 + p['Nxs']-1 + p['Nxp']-1

    # PCA Normalize the states.
    # ipdb.set_trace()
    c_avgn_concentration = state[:N_cavgn]
    c_avgp_concentration = state[N_cavgn : (N_cavgn + N_cavgp)]
    c_ex_concentration = state[(N_cavgn+N_cavgp):(N_cavgn+N_cavgp+N_cex)]

    time_states = np.concatenate((c_avgn_concentration, c_avgp_concentration, c_ex_concentration), axis=0)
    time_states_arr = time_states.reshape([time_states.shape[0],1])
    standard_states_arr = (time_states_arr - data_mu)/data_std
    pca_states_arr = np.dot(data_PCA, standard_states_arr)
    pca_states_arr_nmz = pca_states_arr / LA.norm(pca_states_arr,2)

    pca_states_nmz = pca_states_arr_nmz.reshape([pca_states_arr_nmz.shape[0],]) # arr -> list

    # Temp = (state[-1] - 298 - 10) / (320-298)
    # Temp = np.array([Temp])

    # # Cocatenate
    # first_part = np.concatenate((c_avgn_concentration, c_avgp_concentration, c_ex_concentration), axis=0)
    # second_part = np.concatenate((first_part, Temp), axis=0)

    Temp = (state[-1] - 298 - 10) / (320-298)
    Temp = np.array([Temp])

    second_part = np.concatenate((pca_states_nmz,Temp),axis=0)

    norm_state = second_part

    # solid_concentration=state[:38]
    # electrolyte_concentration=state[38:-1]-1
    # temperature=(state[-1:]*298-298-10)/(320-298)
    # first_part=np.concatenate((solid_concentration,electrolyte_concentration),axis=0)
    # second_part=np.concatenate((first_part,temperature),axis=0)

    # norm_state=second_part

    return norm_state

# %%
def denormalize_input(input_value, min_OUTPUT_value, max_OUTPUT_value):
    
    output_value=(1+input_value)*(max_OUTPUT_value-min_OUTPUT_value)/2+min_OUTPUT_value
    
    return output_value

# %%
import scipy.io as sio

with open("results/training_results/checkpoints_list.txt", "rb") as fp:   # Unpickling
    checkpoints_list = pickle.load(fp)

# %%
for chk_pt in checkpoints_list:
    
    print('iter:{}'.format(chk_pt))
    # Policy
    agent = Agent(state_size=5, action_size=1, random_seed=1)    

    # Load
    returns_list_at_the_end_of_training_without_exploration=[]

    i_episode = chk_pt    
    i_training=1
    
    agent.actor_local.load_state_dict(torch.load('results/training_results/training'+str(i_training)+'/episode'+str(i_episode)+'/checkpoint_actor_'+str(i_episode)+'.pth',map_location='cpu'))
    agent.critic_local.load_state_dict(torch.load('results/training_results/training'+str(i_training)+'/episode'+str(i_episode)+'/checkpoint_critic_'+str(i_episode)+'.pth',map_location='cpu'))
#     agent.actor_local.load_state_dict(torch.load('results/training_results/training'+str(i_training)+'/episode'+str(i_episode)+'/checkpoint_actor_'+str(i_episode)+'.pth'))
#     agent.critic_local.load_state_dict(torch.load('results/training_results/training'+str(i_training)+'/episode'+str(i_episode)+'/checkpoint_critic_'+str(i_episode)+'.pth'))

    # Set Env
    env = DFN(sett=settings, cont_sett=control_settings)
    
    # Set Init.
    init_V = 3.5
    init_T = 300
    state = env.reset(init_v = init_V, init_t=init_T)
    norm_state = normalize_states(state)

    # Set vectors to save
    ACTION_VEC=[]
    SOC_VEC=[]
    T_VEC=[]
    VOLTAGE_VEC=[]
    RETURN_VALUE=0
    TIME_VEC = []
    done=False

    cex_sim = []
    etasLn_sim = []
    cssn_sim = []
    cssp_sim = []
    cavgn_sim = []
    cavgp_sim = []
    nLis_sim = []
    phi_s_n_sim = []
    phi_s_p_sim = []
    ien_sim = []
    iep_sim = []
    jn_sim =[]
    jp_sim = []
    phi_e_sim = []
    
    action_test_vec = np.linspace(-1,1,num=100)
    q_value_test_vec = []
    


    tt=0
    TIME_VEC.append(tt)

    for t in range(10000):

        # the exploration noise has been disabled
        norm_action = agent.act(norm_state, add_noise=False)
        
        # save Q-function info
        idx = 0
        q_value_test = np.ones([100,1])
        for action_test in action_test_vec:
            tensor1=torch.tensor([action_test],requires_grad=True)
            tensor2=tensor1.detach().numpy()
            q_val_tensor = agent.critic_local(torch.from_numpy(norm_state).float().reshape(1,-1),torch.from_numpy(tensor2).float().reshape(1,-1))
            q_value_test[idx,:]=(q_val_tensor[0].tolist())
            idx += 1
        q_value_test_vec.append(q_value_test)
        
        # Apply action.
        applied_action=denormalize_input(norm_action,
                                                 env.action_space.low[0],
                                                 env.action_space.high[0])    
        applied_action=applied_action
        next_state,reward,done,b=env.step(applied_action)
        norm_next_state=normalize_states(next_state)
        RETURN_VALUE+=reward

        #save the simulation vectors
        ACTION_VEC.append(applied_action[0])
        SOC_VEC.append(env.info['SOCn'])
        T_VEC.append(env.info['T'])

        #save the simulation info
        cex_sim.append(env.c_ex)
        etasLn_sim.append(env.etasLn)
        cssn_sim.append(env.cssn)
        cssp_sim.append(env.cssp)
        cavgn_sim.append(env.c_avgn)
        cavgp_sim.append(env.c_avgp)
        nLis_sim.append(env.nLis)
        
        phi_s_n_sim.append(env.out_phisn)
        phi_s_p_sim.append(env.out_phisp)
        ien_sim.append(env.out_ien)
        iep_sim.append(env.out_iep)
        jn_sim.append(env.out_jn)
        jp_sim.append(env.out_jp)
        phi_e_sim.append(env.out_phie)



        tt += env.dt
        TIME_VEC.append(tt)
        VOLTAGE_VEC.append(env.info['V'])
        norm_state=norm_next_state

        if done or RETURN_VALUE<control_settings['max_negative_score']:
            break
    
    
    q_test = np.array(q_value_test_vec)
    q_test = q_test.reshape([q_test.shape[0],q_test.shape[1]])
    soc_traj = np.array(SOC_VEC)
    
    # Save data
    sio.savemat('LEARNING_TEST_'+str(chk_pt)+'.mat',
                {'time_sim':TIME_VEC,
                 'volt_sim':VOLTAGE_VEC,
                 'current_sim':ACTION_VEC,
                 'temp_sim': T_VEC,
                 'soc_sim' : SOC_VEC, 
                 'cex_sim' : cex_sim,
                 'etasLn_sim' : etasLn_sim,
                 'cssn_sim': cssn_sim,
                 'cssp_sim': cssp_sim,
                 'cavgn_sim': cavgn_sim,
                 'cavgp_sim': cavgp_sim,
                 'nLis_sim': nLis_sim,
                 'phi_s_n_sim': phi_s_n_sim,
                 'phi_s_p_sim': phi_s_p_sim,
                 'ien_sim': ien_sim,
                 'iep_sim': iep_sim,
                 'jn_sim': jn_sim,
                 'jp_sim': jp_sim,
                 'rwd_sim': RETURN_VALUE, 
                 'phi_e_sim': phi_e_sim,
                 'q_test': q_test,
                 'act_test':action_test_vec})
# Out:
# iter:0
# /Users/Shpark/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# iter:10
# iter:20
# iter:30

# %% [markdown]
# ## 2. Generate Learning-figures
#
# In this section, we aim to generate the learning plot. From the data saved at each 10-th episode, we plot the control input over learning iterations.
#
#
# If you have already saved the data, then you can jump to this section.

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np
from IPython.display import display, clear_output

# %% [markdown]
# ## Showing animation directly

# %%
data_init = sio.loadmat('learning_test/LEARNING_TEST_0.mat')

etasLn_th = control_settings['constraints']['etasLn']['min']
Temp_th = control_settings['constraints']['temperature']['max']
time_max = 150
time_max_vec = np.arange(0,150*60,settings['sample_time'])

episode_max = settings['number_of_training_episodes']
episode_step = settings['periodic_test']
episode_vec = np.arange(0,episode_max+episode_step,episode_step)

step = 0
cum_rwd_episode = []

for chk_pt in checkpoints_list:
    data = sio.loadmat('learning_test/LEARNING_TEST_'+str(chk_pt)+'.mat')

    fig = plt.figure(figsize=(16,12))
    grid = plt.GridSpec(3,2,hspace=1.5, wspace=0.5)
    rwd_plt = fig.add_subplot(grid[0,:])
    cur_plt = fig.add_subplot(grid[1,0])
    volt_plt = fig.add_subplot(grid[1,1])
    temp_plt = fig.add_subplot(grid[2,0])
    etas_plt = fig.add_subplot(grid[2,1])

    rwd_episode = data['rwd_sim'][0]
    cum_rwd_episode.append(rwd_episode)
    rwd_plt.plot(episode_vec[:(step+1)], cum_rwd_episode,linewidth=4)

    cur_plt.plot(data['time_sim'][0][:-1]/60,data['current_sim'][0],linewidth=4)
    cur_plt.text(time_max_vec[80]/60, -130, str(round(data['time_sim'][0][-1]/60,2))+'min',style='italic',fontsize=30,bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
    volt_plt.plot(data['time_sim'][0][:-1]/60,data['volt_sim'][0],linewidth=4)
    temp_plt.plot(data['time_sim'][0][:-1]/60,data['temp_sim']-273,linewidth=4)
    temp_plt.plot(time_max_vec,(Temp_th-273)*np.ones([time_max_vec.shape[0]]),'k--')
    etas_plt.plot(data['time_sim'][0][:-1]/60,data['etasLn_sim'],linewidth=4)
    etas_plt.plot(time_max_vec,etasLn_th*np.ones([time_max_vec.shape[0]]),'k--')
    

    rwd_plt.set_title('Episodic reward trajectory ' + 'at training:'+str(chk_pt),fontsize=30)
    rwd_plt.set_xlabel('Episode [-]',fontsize=30)
    rwd_plt.set_ylabel('Reward [-]',fontsize=30)
    rwd_plt.set_xlim((0, episode_max))
    rwd_plt.set_ylim((-30, 0))
    rwd_plt.text(0.85 * episode_max, -25, str(round(data['rwd_sim'][0][0],2)), style='italic', fontsize=30, bbox={'facecolor':'blue','alpha':0.5, 'pad':10} )
    rwd_plt.tick_params(labelsize=30)
    
    cur_plt.set_title('Current trajectory' +'\n'+'at training:'+str(chk_pt),fontsize=30)
    cur_plt.set_xlabel('Time [min]',fontsize=30)
    cur_plt.set_ylabel('Current [A]',fontsize=30)
    cur_plt.set_ylim((-150, 0))
    cur_plt.set_xlim((0, 150))
    cur_plt.tick_params(labelsize=30)
    
    volt_plt.set_title('Voltage trajectory' + '\n' + 'at training:'+str(chk_pt),fontsize=30)
    volt_plt.set_xlabel('Time [min]',fontsize=30)
    volt_plt.set_ylabel('Voltage [V]',fontsize=30)
    volt_plt.set_ylim((2.5, 4.5))
    volt_plt.set_xlim((0, 150))
    volt_plt.tick_params(labelsize=30)
    
    
    temp_plt.set_title('Temperature trajectory' +'\n'+'at training:'+str(chk_pt),fontsize=30)
    temp_plt.set_xlabel('Time [min]',fontsize=30)
    temp_plt.set_ylabel(r'Temperature [$C^{\circ}$]',fontsize=30)
    temp_plt.set_ylim((0, 50))
    temp_plt.set_xlim((0, 150))
    temp_plt.tick_params(labelsize=30)
    
    etas_plt.set_title(r'$\eta_{sr}(L^{-},t)$ trajectory' +'\n'+'at training:'+str(chk_pt),fontsize=30)
    etas_plt.set_xlabel('Time [min]',fontsize=30)
    etas_plt.set_ylabel(r'$\eta_{sr}$ [V]',fontsize=30)
    etas_plt.set_ylim((0, 0.1))
    etas_plt.set_xlim((0, 150))
    etas_plt.tick_params(labelsize=30)
    
    

    step += 1
    clear_output(wait=True)
    display(fig)

    
clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      74         try:
# ---> 75             reduction = getattr(obj, method)
#      76         except AttributeError:
#
# AttributeError: 'bool' object has no attribute 'any'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-26c54e6e8657> in <module>
#      78     step += 1
#      79     clear_output(wait=True)
# ---> 80     display(fig)
#      81
#      82
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/shpark/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1202         renderer.open_group(__name__)
#    1203
# -> 1204         ticks_to_draw = self._update_ticks()
#    1205         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1206                                                                 renderer)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1086             tick.set_label1(label)
#    1087             tick.set_label2(label)
# -> 1088         minor_locs = self.get_minorticklocs()
#    1089         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1090         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1328         """Get the array of minor tick locations in data coordinates."""
#    1329         # Remove minor ticks duplicating major ticks.
# -> 1330         major_locs = self.major.locator()
#    1331         minor_locs = self.minor.locator()
#    1332         transform = self._scale.get_transform()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    2076     def __call__(self):
#    2077         vmin, vmax = self.axis.get_view_interval()
# -> 2078         return self.tick_values(vmin, vmax)
#    2079
#    2080     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2084         vmin, vmax = mtransforms.nonsingular(
#    2085             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2086         locs = self._raw_ticks(vmin, vmax)
#    2087
#    2088         prune = self._prune
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2023         if self._nbins == 'auto':
#    2024             if self.axis is not None:
# -> 2025                 nbins = np.clip(self.axis.get_tick_space(),
#    2026                                 max(1, self._min_n_ticks - 1), 9)
#    2027             else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2501         ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2502         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# -> 2503         tick = self._get_tick(True)
#    2504         # Having a spacing of at least 2 just looks good.
#    2505         size = tick.label1.get_size() * 2.0
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2213         else:
#    2214             tick_kw = self._minor_tick_kw
# -> 2215         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2216
#    2217     def _get_label(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     581                           markersize=self._size,
#     582                           markeredgewidth=self._width,
# --> 583                           zorder=self._zorder)
#     584         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     585         self._set_artist_props(l)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         self._markerfacecoloralt = None
#     396
# --> 397         self.set_markerfacecolor(markerfacecolor)
#     398         self.set_markerfacecoloralt(markerfacecoloralt)
#     399         self.set_markeredgecolor(markeredgecolor)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in set_markerfacecolor(self, fc)
#    1249         if fc is None:
#    1250             fc = 'auto'
# -> 1251         if np.any(self._markerfacecolor != fc):
#    1252             self.stale = True
#    1253         self._markerfacecolor = fc
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2162
#    2163     """
# -> 2164     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2165
#    2166
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      73     if type(obj) is not mu.ndarray:
#      74         try:
# ---> 75             reduction = getattr(obj, method)
#      76         except AttributeError:
#      77             pass
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x1c27e1d400> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     716                     textrenderer.draw_text(gc, x, y, clean_line,
#     717                                            textobj._fontproperties, angle,
# --> 718                                            ismath=ismath, mtext=mtext)
#     719
#     720         gc.restore()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     178             # We pass '0' for angle here, since it will be rotated (in raster
#     179             # space) in the following call to draw_text_image).
# --> 180             font.set_text(s, 0, flags=flags)
#     181         font.draw_glyphs_to_bitmap(antialiased=rcParams['text.antialiased'])
#     182         d = font.get_descent() / 64.0
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x1c2807a158> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/shpark/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1214         # the actual bbox
#    1215
# -> 1216         self._update_label_position(renderer)
#    1217
#    1218         self.label.draw(renderer)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2299         # get bounding boxes for this axis and any siblings
#    2300         # that have been set by `fig.align_ylabels()`
# -> 2301         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2302
#    2303         x, y = self.label.get_position()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2283         # if we want to align labels from other axes:
#    2284         for axx in grp.get_siblings(self.axes):
# -> 2285             ticks_to_draw = axx.yaxis._update_ticks()
#    2286             tlb, tlb2 = axx.yaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2287             bboxes.extend(tlb)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1086             tick.set_label1(label)
#    1087             tick.set_label2(label)
# -> 1088         minor_locs = self.get_minorticklocs()
#    1089         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1090         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1328         """Get the array of minor tick locations in data coordinates."""
#    1329         # Remove minor ticks duplicating major ticks.
# -> 1330         major_locs = self.major.locator()
#    1331         minor_locs = self.minor.locator()
#    1332         transform = self._scale.get_transform()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    2076     def __call__(self):
#    2077         vmin, vmax = self.axis.get_view_interval()
# -> 2078         return self.tick_values(vmin, vmax)
#    2079
#    2080     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2084         vmin, vmax = mtransforms.nonsingular(
#    2085             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2086         locs = self._raw_ticks(vmin, vmax)
#    2087
#    2088         prune = self._prune
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2023         if self._nbins == 'auto':
#    2024             if self.axis is not None:
# -> 2025                 nbins = np.clip(self.axis.get_tick_space(),
#    2026                                 max(1, self._min_n_ticks - 1), 9)
#    2027             else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2505         size = tick.label1.get_size() * 2.0
#    2506         if size > 0:
# -> 2507             return int(np.floor(length / size))
#    2508         else:
#    2509             return 2**31 - 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save as an animated file

# %%
from matplotlib import pyplot as plt
from celluloid import Camera
import time
import matplotlib.animation as animation

data_init = sio.loadmat('learning_test/LEARNING_TEST_0.mat')

time_max = 150
time_max_vec = np.arange(0,150*60,settings['sample_time'])


episode_max = settings['number_of_training_episodes']
episode_step = settings['periodic_test']
episode_vec = np.arange(0,episode_max+episode_step,episode_step)

step = 0
cum_rwd_episode = []


fig = plt.figure(figsize=(16,12))
grid = plt.GridSpec(3,2,hspace=1.5, wspace=0.5)
rwd_plt = fig.add_subplot(grid[0,:])
cur_plt = fig.add_subplot(grid[1,0])
volt_plt = fig.add_subplot(grid[1,1])
temp_plt = fig.add_subplot(grid[2,0])
etas_plt = fig.add_subplot(grid[2,1])
camera = Camera(fig)

    
for chk_pt in checkpoints_list:
    data = sio.loadmat('learning_test/LEARNING_TEST_'+str(chk_pt)+'.mat')
    
    
    rwd_episode = data['rwd_sim'][0]
    cum_rwd_episode.append(rwd_episode)
    rwd_plt.plot(episode_vec[:(step+1)], cum_rwd_episode,linewidth=4)
    
    cur_plt.plot(data['time_sim'][0][:-1]/60,data['current_sim'][0],linewidth=4)
    cur_plt.text(time_max_vec[80]/60, -130, str(round(data['time_sim'][0][-1]/60,2))+'min',style='italic',fontsize=30,bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
    volt_plt.plot(data['time_sim'][0][:-1]/60,data['volt_sim'][0],linewidth=4)
    temp_plt.plot(data['time_sim'][0][:-1]/60,data['temp_sim']-273,linewidth=4)
    temp_plt.plot(time_max_vec,47*np.ones([time_max_vec.shape[0]]),'k--')
    etas_plt.plot(data['time_sim'][0][:-1]/60,data['etasLn_sim'],linewidth=4)
    etas_plt.plot(time_max_vec,0.07*np.ones([time_max_vec.shape[0]]),'k--')  

    
    rwd_plt.set_title('Episodic reward trajectory ' + 'at training:',fontsize=30)
    rwd_plt.set_xlabel('Episode [-]',fontsize=30)
    rwd_plt.set_ylabel('Reward [-]',fontsize=30)
    rwd_plt.set_xlim((0, episode_max))
    rwd_plt.set_ylim((-30, 0))
    rwd_plt.text(0.85 * episode_max, -25, str(round(data['rwd_sim'][0][0],2)), style='italic', fontsize=30, bbox={'facecolor':'blue','alpha':0.5, 'pad':10} )
    # update training number
    data_height = 0
    data_width = episode_max
    rwd_plt.text(data_width*0.83, data_height * (1 + 0.05), str(chk_pt), fontsize=30)
    rwd_plt.tick_params(labelsize=30)

    
    cur_plt.set_title('Current trajectory' + '\n' + 'at training:',fontsize=30)    
    cur_plt.text(time_max_vec[80]/60, -130, str(round(data['time_sim'][0][-1]/60,2))+'min',style='italic',fontsize=30,bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
    cur_plt.set_xlabel('Time [min]',fontsize=30)
    cur_plt.set_ylabel('Current [A]',fontsize=30)
    cur_plt.set_ylim((-150, 0))
    cur_plt.set_xlim((0, 150))
    # update training number
    data_height = 0
    data_width = 150
    cur_plt.text(data_width*0.75, data_height * (1 + 0.01), str(chk_pt), fontsize=30)
    cur_plt.tick_params(labelsize=30)
    
    
    volt_plt.set_title('Voltage trajectory' + '\n' + 'at training:',fontsize=30)
    volt_plt.set_xlabel('Time [min]',fontsize=30)
    volt_plt.set_ylabel('Voltage [V]',fontsize=30)
    volt_plt.set_ylim((2.5, 4.5))
    volt_plt.set_xlim((0, 150))
    # update training number
    data_height = 4.5
    data_width = 150
    volt_plt.text(data_width*0.75, data_height * (1 + 0.01), str(chk_pt), fontsize=30)
    volt_plt.tick_params(labelsize=30)
    
    
    temp_plt.set_title('Temperature trajectory' +'\n'+'at training:',fontsize=30)
    temp_plt.set_xlabel('Time [min]',fontsize=30)
    temp_plt.set_ylabel(r'Temperature [$C^{\circ}$]',fontsize=30)
    temp_plt.set_ylim((0, 50))
    temp_plt.set_xlim((0, 150))
    # update training number
    data_height = 50
    data_width = 150
    temp_plt.text(data_width*0.75, data_height * (1 + 0.01), str(chk_pt), fontsize=30)
    temp_plt.tick_params(labelsize=30)
    
    
    etas_plt.set_title(r'$\eta_{sr}(L^{-},t)$ trajectory' +'\n'+'at training:',fontsize=30)
    etas_plt.set_xlabel('Time [min]',fontsize=30)
    etas_plt.set_ylabel(r'$\eta_{sr}$ [V]',fontsize=30)
    etas_plt.set_ylim((0, 0.1))
    etas_plt.set_xlim((0, 150))
    # update training number
    data_height = 0.1
    data_width = 150
    etas_plt.text(data_width*0.75, data_height * (1 + 0.01), str(chk_pt), fontsize=30)
    etas_plt.tick_params(labelsize=30)
    
    step += 1
    camera.snap()

    
animation = camera.animate()

animation.save('learning_figure.gif', writer = 'imagemagick')

# %% [markdown]
# ## 3. Generate State-EVOLUTION figures
#
# Compared to previous section, this section focuses on SINGLE data file and plot the evolution of the states.

# %% [markdown]
# ## Showing animation directly
#
# ### 1. States

# %%
# Load data
data = sio.loadmat('learning_test/LEARNING_TEST_3000.mat')

# %%
test=data['current_sim']

# %%
time_sim = data['time_sim']
time_vec = time_sim.reshape([time_sim.shape[1],])


xn_size = p['Nxn']-1 # number of discretization points in anode.
xn_vec_sim = np.arange(0,xn_size)

xs_size = p['Nxs']-1 # number of discretization points in separator.
xs_vec_sim = np.arange(0,xs_size)

xp_size = p['Nxp']-1 # number of discretization points in cathode
xp_vec_sim = np.arange(0,xp_size)

x_vec_size = p['Nxn'] + p['Nxs'] + p['Nxp'] - 3
x_vec_sim = np.arange(0,x_vec_size)


c_avgn_sim = data['cavgn_sim']
c_avgn_sim = c_avgn_sim.reshape([c_avgn_sim.shape[0],c_avgn_sim.shape[1]])
c_avgn_sim = c_avgn_sim.T

c_avgp_sim = data['cavgp_sim']
c_avgp_sim = c_avgp_sim.reshape([c_avgp_sim.shape[0],c_avgp_sim.shape[1]])
c_avgp_sim = c_avgp_sim.T

c_ssn_sim = data['cssn_sim']
c_ssn_sim = c_ssn_sim.reshape([c_ssn_sim.shape[0],c_ssn_sim.shape[1]])
c_ssn_sim = c_ssn_sim.T

c_ssp_sim = data['cssp_sim']
c_ssp_sim = c_ssp_sim.reshape([c_ssp_sim.shape[0],c_ssp_sim.shape[1]])
c_ssp_sim = c_ssp_sim.T

c_ex_sim = data['cex_sim']
c_ex_sim = c_ex_sim.reshape([c_ex_sim.shape[0],c_ex_sim.shape[1]])
c_ex_sim = c_ex_sim.T

temp_sim = data['temp_sim']
temp_sim = temp_sim.reshape([temp_sim.shape[0],])# shape:(,NT)
soc_sim = data['soc_sim']
soc_sim = soc_sim.reshape([soc_sim.shape[1],]) # shape:(,NT)

cur_sim = data['current_sim']


fs = 30
lw = 4


for tt in range(time_sim.shape[1]):
    
    # Figure setting
    fig = plt.figure(figsize=(16,12))
    grid = plt.GridSpec(6,3,hspace=1.0, wspace=0.1)
    cssn_plt = fig.add_subplot(grid[0,0])
    cssp_plt = fig.add_subplot(grid[0,2])
    cavgn_plt = fig.add_subplot(grid[1,0])
    cavgp_plt = fig.add_subplot(grid[1,2])
    cex_plt = fig.add_subplot(grid[2,:])
    temp_plt = fig.add_subplot(grid[3,:])
    soc_plt = fig.add_subplot(grid[4,:])
    cur_plt = fig.add_subplot(grid[5,:])
    
    cssn_plt.plot(xn_vec_sim,c_ssn_sim[:,tt]/p['c_s_n_max'],LineWidth=lw)
    cssn_plt.set_xlim((0,xn_vec_sim[-1]))
    cssn_plt.set_ylim((0,1.5))
    cssn_plt.set_xlabel('x in Anode',fontsize=fs)
    cssn_plt.set_ylabel(r'$c^{-}_{ss}/c^{-}_{max}$',fontsize=fs)
    cssn_plt.tick_params(labelsize=fs)

    cssp_plt.plot(xp_vec_sim,c_ssp_sim[:,tt]/p['c_s_p_max'],LineWidth=lw)
    cssp_plt.set_xlim((0,xp_vec_sim[-1]))
    cssp_plt.set_ylim((0,1.5))
    cssp_plt.set_xlabel('x in Cathode',fontsize=fs)
    cssp_plt.set_ylabel(r'$c^{+}_{ss}/c^{+}_{max}$',fontsize=fs)
    cssp_plt.tick_params(labelsize=fs)
    
    cavgn_plt.plot(xn_vec_sim,c_avgn_sim[:,tt]/p['c_s_n_max'],LineWidth=lw)
    cavgn_plt.set_xlim((0,xn_vec_sim[-1]))
    cavgn_plt.set_ylim((0,1))
    cavgn_plt.set_xlabel('x',fontsize=fs)
    cavgn_plt.set_ylabel(r'$c^{-}_{avg}/c^{-}_{max}$',fontsize=fs)
    cavgn_plt.tick_params(labelsize=fs)
    
    cavgp_plt.plot(xp_vec_sim,c_avgp_sim[:,tt]/p['c_s_p_max'],LineWidth=lw)
    cavgp_plt.set_xlim((0,xp_vec_sim[-1]))
    cavgp_plt.set_ylim((0,1))
    cavgp_plt.set_xlabel('x',fontsize=fs)
    cavgp_plt.set_ylabel(r'$c^{+}_{avg}/c^{+}_{max}$',fontsize=fs)
    cavgp_plt.tick_params(labelsize=fs)
    
    cex_plt.plot(x_vec_sim,c_ex_sim[:,tt],LineWidth=lw)
    cex_plt.set_xlim((0,x_vec_sim[-1]))
    cex_plt.set_ylim((100, 2000))
    cex_plt.set_xlabel('x',fontsize=fs)
    cex_plt.set_ylabel(r'$c_e(x,t)$',fontsize=fs)
    cex_plt.tick_params(labelsize=fs)

    temp_plt.plot(time_vec[:tt]/60,temp_sim[:tt],LineWidth=lw)
    temp_plt.set_ylim((298, 340))
    temp_plt.set_xlim((0,time_vec[-1]/60))
    temp_plt.set_xlabel('time [min]',fontsize=fs)
    temp_plt.set_ylabel('Temp [K]',fontsize=fs)
    temp_plt.tick_params(labelsize=fs)
    
    soc_plt.plot(time_vec[:tt]/60,soc_sim[:tt],LineWidth=lw)
    soc_plt.set_ylim((0,1))
    soc_plt.set_xlim((0,time_vec[-1]/60))
    soc_plt.set_xlabel('x',fontsize=fs)
    soc_plt.set_ylabel('SOC [-]',fontsize=fs)
    soc_plt.tick_params(labelsize=fs)
    
    cur_plt.plot(time_vec[:tt]/60, cur_sim[0,:tt], LineWidth=lw)
    cur_plt.set_ylim((-150,0))
    cur_plt.set_xlim((0,time_vec[-1]/60))
    cur_plt.set_xlabel('time [min]',fontsize=fs)
    cur_plt.set_ylabel('Current [A]',fontsize=fs)
    cur_plt.tick_params(labelsize=fs)

    clear_output(wait=True)
    display(fig)

clear_output(wait=True)

# %% [markdown]
# ### 2. Algebraic States

# %%
phi_s_n_sim = data['phi_s_n_sim']
phi_s_n_sim = phi_s_n_sim.reshape([phi_s_n_sim.shape[0],phi_s_n_sim.shape[1]])
phi_s_n_sim = phi_s_n_sim.T

phi_s_p_sim = data['phi_s_p_sim']
phi_s_p_sim = phi_s_p_sim.reshape([phi_s_p_sim.shape[0],phi_s_p_sim.shape[1]])
phi_s_p_sim = phi_s_p_sim.T

ien_sim = data['ien_sim']
ien_sim = ien_sim.reshape([ien_sim.shape[0],ien_sim.shape[1]])
ien_sim = ien_sim.T

iep_sim = data['iep_sim']
iep_sim = iep_sim.reshape([iep_sim.shape[0],iep_sim.shape[1]])
iep_sim = iep_sim.T

jn_sim = data['jn_sim']
jn_sim = jn_sim.reshape([jn_sim.shape[0],jn_sim.shape[1]])
jn_sim = jn_sim.T

jp_sim = data['jp_sim']
jp_sim = jp_sim.reshape([jp_sim.shape[0],jp_sim.shape[1]])
jp_sim = jp_sim.T

phi_e_sim = data['phi_e_sim']
phi_e_sim = phi_e_sim.reshape([phi_e_sim.shape[0],phi_e_sim.shape[1]])
phi_e_sim = phi_e_sim.T

x_vec_phie_size = p['Nx']-1 
x_vec_phie = np.arange(0,x_vec_phie_size)

etasLn_sim = data['etasLn_sim']
etasLn_sim = etasLn_sim.reshape([etasLn_sim.shape[0],]) # shape [1,]

fs = 30
lw = 4


for tt in range(time_sim.shape[1]):
    
    # Figure setting
    fig = plt.figure(figsize=(16,12))
    grid = plt.GridSpec(5,3,hspace=1.0, wspace=0.1)
    phisn_plt = fig.add_subplot(grid[0,0])
    phisp_plt = fig.add_subplot(grid[0,2])
    ien_plt = fig.add_subplot(grid[1,0])
    iep_plt = fig.add_subplot(grid[1,2])
    jn_plt = fig.add_subplot(grid[2,0])
    jp_plt = fig.add_subplot(grid[2,2])
    phie_plt = fig.add_subplot(grid[3,:])
    etasLn_plt = fig.add_subplot(grid[4,:])
    

    
    phisn_plt.plot(xn_vec_sim,phi_s_n_sim[:,tt],LineWidth=lw)
#     phisn_plt.set_xlim((0,xn_vec_sim[-1]))
#     phisn_plt.set_ylim((np.min(phi_s_n_sim),np.max(phi_s_n_sim)))
    phisn_plt.set_xlabel('x in Anode',fontsize=fs)
    phisn_plt.set_ylabel(r'$\phi^{-}_{s}(x,t)$',fontsize=fs)
    phisn_plt.tick_params(labelsize=fs)

    phisp_plt.plot(xp_vec_sim,phi_s_p_sim[:,tt],LineWidth=lw)
#     phisp_plt.set_xlim((0,xp_vec_sim[-1]))
#     phisp_plt.set_ylim((np.min(phi_s_p_sim),np.max(phi_s_p_sim)))
    phisp_plt.set_xlabel('x in Cathode',fontsize=fs)
    phisp_plt.set_ylabel(r'$\phi^{+}_{s}(x,t)$',fontsize=fs)
    phisp_plt.tick_params(labelsize=fs)
    
    ien_plt.plot(xn_vec_sim,ien_sim[:,tt],LineWidth=lw)
#     ien_plt.set_xlim((0,xn_vec_sim[-1]))
#     ien_plt.set_ylim((np.min(ien_sim),np.max(ien_sim)))
    ien_plt.set_xlabel('x in Anode',fontsize=fs)
    ien_plt.set_ylabel(r'$i^{-}_{e}(x,t)$',fontsize=fs)
    ien_plt.tick_params(labelsize=fs)
    
    iep_plt.plot(xp_vec_sim,iep_sim[:,tt],LineWidth=lw)
#     iep_plt.set_xlim((0,xp_vec_sim[-1]))
#     iep_plt.set_ylim((0,1))
    iep_plt.set_xlabel('x in Cathode',fontsize=fs)
    iep_plt.set_ylabel(r'$i^{+}_{e}(x,t)$',fontsize=fs)
    iep_plt.tick_params(labelsize=fs)
    
    jn_plt.plot(xn_vec_sim,jn_sim[:,tt],LineWidth=lw)
#     jn_plt.set_xlim((0,xn_vec_sim[-1]))
#     jn_plt.set_ylim((0, 1))
    jn_plt.set_xlabel('x in Anode',fontsize=fs)
    jn_plt.set_ylabel(r'$j^{-}_{n}(x,t)$',fontsize=fs)
    jn_plt.tick_params(labelsize=fs)

    jp_plt.plot(xp_vec_sim,jp_sim[:,tt],LineWidth=lw)
#     jp_plt.set_xlim((0,xp_vec_sim[-1]))
#     jp_plt.set_ylim((0, 1))
    jp_plt.set_xlabel('x in Cathode',fontsize=fs)
    jp_plt.set_ylabel(r'$j^{+}_{n}(x,t)$',fontsize=fs)
    jp_plt.tick_params(labelsize=fs)
    
    phie_plt.plot(x_vec_phie,phi_e_sim[:,tt],LineWidth=lw)
#     phie_plt.set_xlim((0,x_vec_phie[-1]))
#     phie_plt.set_ylim((0, 0.2))
    phie_plt.set_xlabel('x',fontsize=fs)
    phie_plt.set_ylabel(r'$\phi_{e}(x,t)$',fontsize=fs)
    phie_plt.tick_params(labelsize=fs)
    
    etasLn_plt.plot(time_vec[:tt]/60,etasLn_sim[:tt],LineWidth=lw)
#     etasLn_plt.set_ylim((0,0.15))
#     etasLn_plt.set_xlim((0,time_vec[-1]/60))
    etasLn_plt.set_xlabel('Time [min]',fontsize=fs)
    etasLn_plt.set_ylabel(r'$\eta_{sr}(L^{-},t)$ [V]',fontsize=fs)
    etasLn_plt.tick_params(labelsize=fs)
    
#     ipdb.set_trace()


    clear_output(wait=True)
    display(fig)

clear_output(wait=True)

# %% [markdown]
# ## Save as an animated file
# ### 1. States

# %%
# Load data
data = sio.loadmat('learning_test/LEARNING_TEST_3000.mat')

# %%
from matplotlib import pyplot as plt
from celluloid import Camera
import time
import matplotlib.animation as animation


time_sim = data['time_sim']
time_vec = time_sim.reshape([time_sim.shape[1],])


xn_size = p['Nxn']-1 # number of discretization points in anode.
xn_vec_sim = np.arange(0,xn_size)

xs_size = p['Nxs']-1 # number of discretization points in separator.
xs_vec_sim = np.arange(0,xs_size)

xp_size = p['Nxp']-1 # number of discretization points in cathode
xp_vec_sim = np.arange(0,xp_size)

x_vec_size = p['Nxn'] + p['Nxs'] + p['Nxp'] - 3
x_vec_sim = np.arange(0,x_vec_size)


c_avgn_sim = data['cavgn_sim']
c_avgn_sim = c_avgn_sim.reshape([c_avgn_sim.shape[0],c_avgn_sim.shape[1]])
c_avgn_sim = c_avgn_sim.T

c_avgp_sim = data['cavgp_sim']
c_avgp_sim = c_avgp_sim.reshape([c_avgp_sim.shape[0],c_avgp_sim.shape[1]])
c_avgp_sim = c_avgp_sim.T

c_ssn_sim = data['cssn_sim']
c_ssn_sim = c_ssn_sim.reshape([c_ssn_sim.shape[0],c_ssn_sim.shape[1]])
c_ssn_sim = c_ssn_sim.T

c_ssp_sim = data['cssp_sim']
c_ssp_sim = c_ssp_sim.reshape([c_ssp_sim.shape[0],c_ssp_sim.shape[1]])
c_ssp_sim = c_ssp_sim.T

c_ex_sim = data['cex_sim']
c_ex_sim = c_ex_sim.reshape([c_ex_sim.shape[0],c_ex_sim.shape[1]])
c_ex_sim = c_ex_sim.T

temp_sim = data['temp_sim']
temp_sim = temp_sim.reshape([temp_sim.shape[0],])# shape:(,NT)
soc_sim = data['soc_sim']
soc_sim = soc_sim.reshape([soc_sim.shape[1],]) # shape:(,NT)


fs = 30
lw = 4


# Figure setting
fig = plt.figure(figsize=(20,15))
grid = plt.GridSpec(6,3,hspace=1.0, wspace=0.1)
cssn_plt = fig.add_subplot(grid[0,0])
cssp_plt = fig.add_subplot(grid[0,2])
cavgn_plt = fig.add_subplot(grid[1,0])
cavgp_plt = fig.add_subplot(grid[1,2])
cex_plt = fig.add_subplot(grid[2,:])
temp_plt = fig.add_subplot(grid[3,:])
soc_plt = fig.add_subplot(grid[4,:])
cur_plt = fig.add_subplot(grid[5,:])
camera = Camera(fig)


for tt in range(time_sim.shape[1]-1):
    

    
    cssn_plt.plot(xn_vec_sim,c_ssn_sim[:,tt]/p['c_s_n_max'],LineWidth=lw)
    cssn_plt.set_xlim((0,xn_vec_sim[-1]))
    cssn_plt.set_ylim((0,1.5))
    cssn_plt.set_xlabel('x in Anode',fontsize=fs)
    cssn_plt.set_ylabel(r'$c^{-}_{ss}/c^{-}_{max}$',fontsize=fs)
    cssn_plt.tick_params(labelsize=fs)

    cssp_plt.plot(xp_vec_sim,c_ssp_sim[:,tt]/p['c_s_p_max'],LineWidth=lw)
    cssp_plt.set_xlim((0,xp_vec_sim[-1]))
    cssp_plt.set_ylim((0,1.5))
    cssp_plt.set_xlabel('x in Cathode',fontsize=fs)
    cssp_plt.set_ylabel(r'$c^{+}_{ss}/c^{+}_{max}$',fontsize=fs)
    cssp_plt.tick_params(labelsize=fs)
    
    cavgn_plt.plot(xn_vec_sim,c_avgn_sim[:,tt]/p['c_s_n_max'],LineWidth=lw)
    cavgn_plt.set_xlim((0,xn_vec_sim[-1]))
    cavgn_plt.set_ylim((0,1.5))
    cavgn_plt.set_xlabel('x',fontsize=fs)
    cavgn_plt.set_ylabel(r'$c^{-}_{avg}/c^{-}_{max}$',fontsize=fs)
    cavgn_plt.tick_params(labelsize=fs)
    
    cavgp_plt.plot(xp_vec_sim,c_avgp_sim[:,tt]/p['c_s_p_max'],LineWidth=lw)
    cavgp_plt.set_xlim((0,xp_vec_sim[-1]))
    cavgp_plt.set_ylim((0,1.5))
    cavgp_plt.set_xlabel('x',fontsize=fs)
    cavgp_plt.set_ylabel(r'$c^{+}_{avg}/c^{+}_{max}$',fontsize=fs)
    cavgp_plt.tick_params(labelsize=fs)
    
    cex_plt.plot(x_vec_sim,c_ex_sim[:,tt],LineWidth=lw)
    cex_plt.set_xlim((0,x_vec_sim[-1]))
    cex_plt.set_ylim((100, 2000))
    cex_plt.set_xlabel('x',fontsize=fs)
    cex_plt.set_ylabel(r'$c_e(x,t)$',fontsize=fs)
    cex_plt.tick_params(labelsize=fs)

    temp_plt.plot(time_vec[:tt]/60,temp_sim[:tt],LineWidth=lw)
    temp_plt.set_ylim((298, 340))
    temp_plt.set_xlim((0,time_vec[-1]/60))
    temp_plt.set_xlabel('time [min]',fontsize=fs)
    temp_plt.set_ylabel('Temp [K]',fontsize=fs)
    temp_plt.tick_params(labelsize=fs)
    
    soc_plt.plot(time_vec[:tt]/60,soc_sim[:tt],LineWidth=lw)
    soc_plt.set_ylim((0,1))
    soc_plt.set_xlim((0,time_vec[-1]/60))
    soc_plt.set_xlabel('x',fontsize=fs)
    soc_plt.set_ylabel('SOC [-]',fontsize=fs)
    soc_plt.tick_params(labelsize=fs)
    
    cur_plt.plot(time_vec[:tt]/60, cur_sim[0,:tt], LineWidth=lw)
    cur_plt.set_ylim((-150,0))
    cur_plt.set_xlim((0,time_vec[-1]/60))
    cur_plt.set_xlabel('time [min]',fontsize=fs)
    cur_plt.set_ylabel('Current [A]',fontsize=fs)
    cur_plt.tick_params(labelsize=fs)
    

    camera.snap()


animation = camera.animate()

animation.save('states_figure.gif', writer = 'imagemagick')

# %% [markdown]
# ### 2. Algebraic States

# %%
from matplotlib.ticker import FuncFormatter


phi_s_n_sim_ = data['phi_s_n_sim']
phi_s_n_sim_ = phi_s_n_sim_.reshape([phi_s_n_sim_.shape[0],phi_s_n_sim_.shape[1]])
phi_s_n_sim_ = phi_s_n_sim_.T

phi_s_p_sim_ = data['phi_s_p_sim']
phi_s_p_sim_ = phi_s_p_sim_.reshape([phi_s_p_sim_.shape[0],phi_s_p_sim_.shape[1]])
phi_s_p_sim_ = phi_s_p_sim_.T

ien_sim_ = data['ien_sim']
ien_sim_ = ien_sim_.reshape([ien_sim_.shape[0],ien_sim_.shape[1]])
ien_sim_ = ien_sim_.T

iep_sim_ = data['iep_sim']
iep_sim_ = iep_sim_.reshape([iep_sim_.shape[0],iep_sim_.shape[1]])
iep_sim_ = iep_sim_.T

jn_sim_ = data['jn_sim']
jn_sim_ = jn_sim_.reshape([jn_sim_.shape[0],jn_sim_.shape[1]])
jn_sim_ = jn_sim_.T

jp_sim_ = data['jp_sim']
jp_sim_ = jp_sim_.reshape([jp_sim_.shape[0],jp_sim_.shape[1]])
jp_sim_ = jp_sim_.T

phi_e_sim_ = data['phi_e_sim']
phi_e_sim_ = phi_e_sim_.reshape([phi_e_sim_.shape[0],phi_e_sim_.shape[1]])
phi_e_sim_ = phi_e_sim_.T

x_vec_phie_size = p['Nx']-1 
x_vec_phie = np.arange(0,x_vec_phie_size)

etasLn_sim_ = data['etasLn_sim']
etasLn_sim_ = etasLn_sim_.reshape([etasLn_sim_.shape[0],]) # shape [1,]

fs = 30
lw = 4

# Figure setting
fig = plt.figure(figsize=(16,12))
grid = plt.GridSpec(5,3,hspace=1.0, wspace=0.1)
phisn_plt = fig.add_subplot(grid[0,0])
phisp_plt = fig.add_subplot(grid[0,2])
ien_plt = fig.add_subplot(grid[1,0])
iep_plt = fig.add_subplot(grid[1,2])
jn_plt = fig.add_subplot(grid[2,0])
jp_plt = fig.add_subplot(grid[2,2])
phie_plt = fig.add_subplot(grid[3,:])
etasLn_plt = fig.add_subplot(grid[4,:])
camera = Camera(fig)


for tt in range(time_sim.shape[1]-1):
    
    
    phisn_plt.plot(xn_vec_sim,phi_s_n_sim_[:,tt],LineWidth=lw)
    phisn_plt.set_xlabel('x in Anode',fontsize=fs)
    phisn_plt.set_ylabel(r'$\phi^{-}_{s}(x,t)$',fontsize=fs)
    phisn_plt.tick_params(labelsize=fs)

    phisp_plt.plot(xp_vec_sim,phi_s_p_sim_[:,tt],LineWidth=lw)
    phisp_plt.set_xlabel('x in Cathode',fontsize=fs)
    phisp_plt.set_ylabel(r'$\phi^{+}_{s}(x,t)$',fontsize=fs)
    phisp_plt.tick_params(labelsize=fs)
    
    ien_plt.plot(xn_vec_sim,ien_sim_[:,tt],LineWidth=lw)
    ien_plt.set_xlabel('x in Anode',fontsize=fs)
    ien_plt.set_ylabel(r'$i^{-}_{e}(x,t)$',fontsize=fs)
    ien_plt.tick_params(labelsize=fs)
    
    iep_plt.plot(xp_vec_sim,iep_sim_[:,tt],LineWidth=lw)
    iep_plt.set_xlabel('x in Cathode',fontsize=fs)
    iep_plt.set_ylabel(r'$i^{+}_{e}(x,t)$',fontsize=fs)
    iep_plt.tick_params(labelsize=fs)
    
    jn_plt.plot(xn_vec_sim,jn_sim_[:,tt],LineWidth=lw)
    jn_plt.set_xlabel('x in Anode',fontsize=fs)
    jn_plt.set_ylabel(r'$j^{-}_{n}(x,t)$',fontsize=fs)
    jn_plt.tick_params(labelsize=20)
    jn_plt.yaxis.set_major_formatter(FuncFormatter('{:.1e}'.format))

    jp_plt.plot(xp_vec_sim,jp_sim_[:,tt],LineWidth=lw)
    jp_plt.set_xlabel('x in Cathode',fontsize=fs)
    jp_plt.set_ylabel(r'$j^{+}_{n}(x,t)$',fontsize=fs)
    jp_plt.tick_params(labelsize=20)
    jp_plt.yaxis.set_major_formatter(FuncFormatter('{:.1e}'.format))
    
    phie_plt.plot(x_vec_phie,phi_e_sim_[:,tt],LineWidth=lw)
    phie_plt.set_xlabel('x',fontsize=fs)
    phie_plt.set_ylabel(r'$\phi_{e}(x,t)$',fontsize=fs)
    phie_plt.tick_params(labelsize=fs)
    
    etasLn_plt.plot(time_vec[:tt]/60,etasLn_sim_[:tt],LineWidth=lw)
    etasLn_plt.set_xlabel('Time [min]',fontsize=fs)
    etasLn_plt.set_ylabel(r'$\eta_{sr}(L^{-},t)$ [V]',fontsize=fs)
    etasLn_plt.tick_params(labelsize=fs)

#     ipdb.set_trace()

    camera.snap()


animation = camera.animate()

animation.save('algebraic_states_figure.gif', writer = 'imagemagick')

# %% [markdown]
# ## Estimating Value function
#
# Draw Q-function.
